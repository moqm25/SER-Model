# %% [markdown]
# Dataset retrieved from: https://zenodo.org/record/1188976

# %%
pip install numpy==1.21.0
# Out:
# Collecting numpy==1.21.0
#   Downloading numpy-1.21.0-cp39-cp39-macosx_10_9_x86_64.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 8.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# regression 1.0.5 requires numpy==1.23.3, but you have numpy 1.21.0 which is incompatible.
# pandas 1.5.1 requires pytz>=2020.1, but you have pytz 2019.3 which is incompatible.
# optimisation-algorithms 1.1.2 requires numpy==1.23.3, but you have numpy 1.21.0 which is incompatible.
# Successfully installed numpy-1.21.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (0.1.22)
# Requirement already satisfied: click in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: tqdm in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: kaggle in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: python-dateutil in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: urllib3 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from kaggle->opendatasets) (1.26.12)
# Requirement already satisfied: python-slugify in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: six>=1.10 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from kaggle->opendatasets) (2022.9.24)
# Requirement already satisfied: requests in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from kaggle->opendatasets) (2.28.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests->kaggle->opendatasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests->kaggle->opendatasets) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib>=0.14 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.1.1)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: decorator>=4.3.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (4.3.0)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp39-cp39-macosx_10_9_x86_64.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 6.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.2.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.9.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: msgpack>=1.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.3)
# Collecting pooch<1.7,>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 3.4 MB/s eta 0:00:00
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.5 MB/s eta 0:00:00a 0:00:01m
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.21.5)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 8.3 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: setuptools in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (65.5.0)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.9.24)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23703 sha256=5d050e6ade59829e0276c6954f72962646feee4960321dd9c1dd019126c20286
#   Stored in directory: /Users/moiezqamar/Library/Caches/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# Installing collected packages: soxr, lazy-loader, audioread, soundfile, pooch, librosa
# Successfully installed audioread-3.0.0 lazy-loader-0.2 librosa-0.10.0.post2 pooch-1.6.0 soundfile-0.12.1 soxr-0.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastai
# Out:
# Requirement already satisfied: fastai in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (2.7.10)
# Requirement already satisfied: fastcore<1.6,>=1.4.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (1.5.27)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: pandas in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (1.5.1)
# Requirement already satisfied: requests in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (2.28.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pyyaml in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (5.4.1)
# Requirement already satisfied: spacy<4 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (3.4.3)
# Requirement already satisfied: torchvision>=0.8.2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (0.14.0)
# Requirement already satisfied: torch<1.14,>=1.7 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (1.13.0)
# Requirement already satisfied: pip in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (22.2.2)
# Requirement already satisfied: scipy in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (1.9.1)
# Requirement already satisfied: pillow>6.0.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (9.2.0)
# Requirement already satisfied: matplotlib in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (3.6.2)
# Requirement already satisfied: scikit-learn in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (1.0.2)
# Requirement already satisfied: packaging in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from fastai) (21.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (8.1.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (3.0.10)
# Requirement already satisfied: setuptools in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (65.5.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (0.8.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: jinja2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (1.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (1.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (1.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (1.21.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (2.4.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from packaging->fastai) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests->fastai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests->fastai) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from requests->fastai) (2022.9.24)
# Requirement already satisfied: typing-extensions in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from torch<1.14,>=1.7->fastai) (4.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->fastai) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->fastai) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->fastai) (1.0.6)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 2.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->fastai) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->fastai) (1.1.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<4->fastai) (5.2.1)
# Requirement already satisfied: six>=1.5 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai) (8.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<4->fastai) (1.1.1)
# Installing collected packages: pytz
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2019.3
#     Uninstalling pytz-2019.3:
#       Successfully uninstalled pytz-2019.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# py-imessage 1.7 requires pytz==2019.3, but you have pytz 2023.3 which is incompatible.
# conda-repo-cli 1.0.24 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.24 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.24 requires PyYAML==6.0, but you have pyyaml 5.4.1 which is incompatible.
# Successfully installed pytz-2023.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sounddevice
# Out:
# Collecting sounddevice
#   Downloading sounddevice-0.4.6-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: CFFI>=1.0 in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from sounddevice) (1.15.1)
# Requirement already satisfied: pycparser in /Users/moiezqamar/opt/anaconda3/lib/python3.9/site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm

import matplotlib.pyplot as plt   # plotting
from matplotlib import image as mpimg

import librosa                    # Python package for music and audio analysis
import librosa.display            # Allows you to display audio files 
import os                         # The OS module in Python provides a way of 
                                  # using operating system dependent functionality.
import scipy.io.wavfile           # Open a WAV files
from scipy.io.wavfile import write

import numpy as np                # Used for working with arrays
import fastai                     
import glob                       # Used to return all file paths that match a specific 
                                  # pattern

import sounddevice as sd


# Import fast AI stuff
from fastai import *                                 
from fastai.vision.all import *
from fastai.vision.data import ImageDataLoaders
from fastai.tabular.all import *
from fastai.text.all import *
from fastai.vision.widgets import *

# %% [markdown]
# # DOWNLOAD DATASET

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/uwrfkaggler/ravdess-emotional-speech-audio")
# use kaggle credentials
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: moiezqamar
# Your Kaggle Key: ········
# Downloading ravdess-emotional-speech-audio.zip to ./ravdess-emotional-speech-audio
# 100%|████████████████████████████████████████| 429M/429M [00:44<00:00, 10.1MB/s]

# %% [markdown]
# # CREATE NEEDED DIRECTORIES

# %%
# !rm -r "./ravdess-emotional-speech-audio/audio_speech_actors_01-24"

# !mkdir './output'
# !mkdir './output/live_images'

# !mkdir './DATASET'
# !mkdir './DATASET/angry'
# !mkdir './DATASET/calm'
# !mkdir './DATASET/disgust'
# !mkdir './DATASET/fearful'
# !mkdir './DATASET/neutral'
# !mkdir './DATASET/sad'
# !mkdir './DATASET/happy'
# !mkdir './DATASET/surprised'

# !mkdir './models'
# Out:
# rm: ./ravdess-emotional-speech-audio/audio_speech_actors_01-24: No such file or directory

# %% [markdown]
# # DEFINING THE PATHS

# %%
AUDIO_FOLDER = "./ravdess-emotional-speech-audio/*"
DATASET = "./DATASET/"


paths = [audioFile for actor in glob.glob(AUDIO_FOLDER) for audioFile in glob.glob(actor +'/*')]

result = [paths[i:i+10] for i in range(0, len(paths), 10)]

# %%
# emotions
dicts = {
    '01' : 'neutral', 
    '02' : 'calm', 
    '03' : 'happy', 
    '04' : 'sad', 
    '05' : 'angry', 
    '06' : 'fearful', 
    '07' : 'disgust', 
    '08' : 'surprised'
}

# %% [markdown]
# # RUN THIS CODE TO CLEAR THE DATASET FOLDER:

# %%
# clear the test1 and train1 folders:
directories = [DATASET] # specify the path to the directory

for directory in directories:
    for foldername in os.listdir(directory):
        folderpath = os.path.join(directory, foldername)
        if os.path.isdir(folderpath):
            for filename in os.listdir(folderpath):
                filepath = os.path.join(folderpath, filename)
                if os.path.isfile(filepath):
                    os.remove(filepath)

# %% [markdown]
# # CONVERT ALL AUDIO FILES TO MELSPECTROGRAM:

# %%
def convert_audio_to_melspectrogram(audioPath, savePath):

    # Load audio file and visualize its waveform (using librosa)
    # The `librosa.load()` function takes two arguments: the path to the audio file and the sample rate.
    # The sample rate is the number of samples per second in the audio file.
    x, sr = librosa.load(audioPath, sr=44100)

    # Trim the audio file to remove silence at the beginning and end.
    # The `librosa.effects.trim()` function takes two arguments: the audio signal and the threshold.
    # The threshold is the minimum amplitude that is considered to be non-silence.
    xt,_=librosa.effects.trim(x)                         

    x=xt

    # Plot the spectrogram.
    # The `librosa.stft()` function computes the short-time Fourier transform of the audio signal.
    # The `librosa.amplitude_to_db()` function converts the amplitude of the spectrogram to decibels.
    X = librosa.stft(x)
    Xdb = librosa.amplitude_to_db(abs(X))

    # Apply log transformation on the loaded audio signals
    # The `librosa.display.specshow()` function plots the spectrogram.
    # The `sr` argument specifies the sample rate of the audio signal.
    # The `x_axis` argument specifies the axis along which the time is displayed.
    # The `y_axis` argument specifies the axis along which the frequency is displayed.
    librosa.display.specshow(Xdb, sr=sr, vmin=-60, vmax=60,x_axis='time', y_axis='log',cmap='magma', ax=None)

    #plt.colorbar()
    
    # Remove the axis
    plt.gca().get_xaxis().set_visible(False)
    plt.gca().get_yaxis().set_visible(False)
    
    # Save the figure.
    # The `plt.savefig()` function saves the figure to a file.
    # The `savePath` argument specifies the path to the file.
    plt.savefig(savePath)
    plt.clf()

# %%
# convert_audio_to_melspectrogram(result[0][0],"./output/sup")
# convert_audio_to_melspectrogram(result[0][1],"./output/sup")
# convert_audio_to_melspectrogram(result[0][2],"./output/sup")

# %%
# Convert the audio files to melspectrograms.
counts = {}
fileLoc=1
for path in result:
    files = tqdm(path)
    for audio_file_path in files:
        files.set_postfix_str(f"{fileLoc}/{len(result)}")
        
        emotion = dicts[audio_file_path[-18:-16]]
        
        count = counts.get(emotion, 1)
        
        # split up test and train data
        p = os.path.join(f"{DATASET}{emotion}", f"{emotion}{str(count).zfill(6)}.jpg")
        
        
        counts[emotion] = count + 1
        
        convert_audio_to_melspectrogram(audio_file_path, p)
    fileLoc+=1
# Out:
# 100%|████████████████████████████████████| 10/10 [00:02<00:00,  3.35it/s, 1/144]
# 100%|████████████████████████████████████| 10/10 [00:03<00:00,  3.18it/s, 2/144]
# 100%|████████████████████████████████████| 10/10 [00:02<00:00,  3.70it/s, 3/144]
# 100%|████████████████████████████████████| 10/10 [00:03<00:00,  2.87it/s, 4/144]
# 100%|████████████████████████████████████| 10/10 [00:02<00:00,  3.43it/s, 5/144]
# 100%|████████████████████████████████████| 10/10 [00:03<00:00,  3.32it/s, 6/144]
# 100%|████████████████████████████████████| 10/10 [00:04<00:00,  2.25it/s, 7/144]
# 100%|████████████████████████████████████| 10/10 [00:04<00:00,  2.06it/s, 8/144]
# 100%|████████████████████████████████████| 10/10 [00:03<00:00,  2.53it/s, 9/144]
# 100%|███████████████████████████████████| 10/10 [00:05<00:00,  1.74it/s, 10/144]
# 100%|███████████████████████████████████| 10/10 [00:05<00:00,  1.70it/s, 11/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.72it/s, 12/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.34it/s, 13/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.28it/s, 14/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.24it/s, 15/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.57it/s, 16/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.72it/s, 17/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.43it/s, 18/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.28it/s, 19/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.21it/s, 20/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.72it/s, 21/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.73it/s, 22/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.14it/s, 23/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.98it/s, 24/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.35it/s, 25/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.00it/s, 26/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.19it/s, 27/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.57it/s, 28/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.19it/s, 29/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.42it/s, 30/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.64it/s, 31/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.46it/s, 32/144]
# 100%|███████████████████████████████████| 10/10 [00:05<00:00,  1.88it/s, 33/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.18it/s, 34/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.31it/s, 35/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.55it/s, 36/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.02it/s, 37/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.12it/s, 38/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.76it/s, 39/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.81it/s, 40/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.90it/s, 41/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.89it/s, 42/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.94it/s, 43/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.74it/s, 44/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.80it/s, 45/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.87it/s, 46/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.82it/s, 47/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.81it/s, 48/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.80it/s, 49/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  4.07it/s, 50/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.49it/s, 51/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.66it/s, 52/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.73it/s, 53/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.52it/s, 54/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.90it/s, 55/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.75it/s, 56/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.51it/s, 57/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.67it/s, 58/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.72it/s, 59/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.84it/s, 60/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.38it/s, 61/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.59it/s, 62/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.61it/s, 63/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.29it/s, 64/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.57it/s, 65/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.46it/s, 66/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.70it/s, 67/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.80it/s, 68/144]
# 100%|███████████████████████████████████| 10/10 [00:04<00:00,  2.45it/s, 69/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.83it/s, 70/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.58it/s, 71/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.90it/s, 72/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.95it/s, 73/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.16it/s, 74/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.18it/s, 75/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.13it/s, 76/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.98it/s, 77/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.02it/s, 78/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.84it/s, 79/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.89it/s, 80/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.09it/s, 81/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.79it/s, 82/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.00it/s, 83/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.54it/s, 84/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.62it/s, 85/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.67it/s, 86/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  4.15it/s, 87/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.67it/s, 88/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.90it/s, 89/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.57it/s, 90/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.34it/s, 91/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.14it/s, 92/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.03it/s, 93/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.12it/s, 94/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.24it/s, 95/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.30it/s, 96/144]
# 100%|███████████████████████████████████| 10/10 [00:02<00:00,  3.42it/s, 97/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  3.21it/s, 98/144]
# 100%|███████████████████████████████████| 10/10 [00:03<00:00,  2.93it/s, 99/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.24it/s, 100/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.49it/s, 101/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.30it/s, 102/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.79it/s, 103/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.14it/s, 104/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.74it/s, 105/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.32it/s, 106/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.66it/s, 107/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.36it/s, 108/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.37it/s, 109/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.25it/s, 110/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.15it/s, 111/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.12it/s, 112/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.17it/s, 113/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.79it/s, 114/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.95it/s, 115/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.90it/s, 116/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.89it/s, 117/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.89it/s, 118/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.87it/s, 119/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.93it/s, 120/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.84it/s, 121/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.55it/s, 122/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.52it/s, 123/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.86it/s, 124/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.57it/s, 125/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.90it/s, 126/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.74it/s, 127/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.91it/s, 128/144]
# 100%|██████████████████████████████████| 10/10 [00:06<00:00,  1.62it/s, 129/144]
# 100%|██████████████████████████████████| 10/10 [00:04<00:00,  2.34it/s, 130/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.55it/s, 131/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.87it/s, 132/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.57it/s, 133/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.60it/s, 134/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.55it/s, 135/144]
# 100%|██████████████████████████████████| 10/10 [00:02<00:00,  3.68it/s, 136/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.20it/s, 137/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  3.11it/s, 138/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.75it/s, 139/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.75it/s, 140/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.82it/s, 141/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.85it/s, 142/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.75it/s, 143/144]
# 100%|██████████████████████████████████| 10/10 [00:03<00:00,  2.50it/s, 144/144]

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

fs=44100
seconds=3
dtype = 'int16'
mic = int(input(f'Of the following list of devices, select which one to use as your microphone:\n{sd.query_devices()}\n>>>'))
count = 1

while true:
    
    print("Recording...")
    
    checkEmotion(count,mic, fs, seconds, dtype)
    
    cont = input("\nContinue? (Y/N): ")
    
    if cont == 'Y' or cont == 'y':
        count+=1
        continue
    else:
        break
# Out:
# Of the following list of devices, select which one to use as your microphone:
# > 0 Built-in Microphone, Core Audio (2 in, 0 out)
# < 1 Built-in Output, Core Audio (0 in, 2 out)
#   2 Microsoft Teams Audio, Core Audio (2 in, 2 out)
#   3 ZoomAudioDevice, Core Audio (2 in, 2 out)
# >>>0
# Recording...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tf/31f0rc1x5k50qxxnbl8gjc1c0000gn/T/ipykernel_81255/3672129341.py in <module>
#      12     print("Recording...")
#      13
# ---> 14     checkEmotion(count,mic, fs, seconds, dtype)
#      15
#      16     cont = input("\nContinue? (Y/N): ")
#
# NameError: name 'checkEmotion' is not defined

# %%
'''loss_functions = [CrossEntropyLossFlat(), LabelSmoothingCrossEntropy(),
                  FocalLossFlat()]
loss_functions1 = ["CrossEntropyLossFlat", "LabelSmoothingCrossEntropy",
                  "FocalLossFlat"]
train_size = [0.2, 0.4, 0.6]

for LF in range(0,3):
    for TS in range(0,3):
        print(f"___________{loss_functions1[LF]} ... {train_size[TS]}___________")
        dls = ImageDataLoaders.from_folder(train_path, valid_pct=train_size[TS], seed=5, num_workers=0)
        print(f"validation: {len(dls.valid_ds.items[:])}  |  training set: {len(dls.train_ds.items[:])}")

        learn = vision_learner(dls, models.resnet34, loss_func=loss_functions[LF], metrics=accuracy)
        lr_min, lr_steep = learn.lr_find(suggest_funcs=(minimum, steep))
        print(f"Minimum/10: {lr_min:.2e}, steepest point: {lr_steep:.2e}")

        learn.fit(10, float(f"{lr_steep:.2e}"))
        #interp = ClassificationInterpretation.from_learner(learn)
        #losses,idxs = interp.top_losses()
        #len(dls.valid_ds)==len(losses)==len(idxs)

        #interp.plot_confusion_matrix(figsize=(8,8), dpi=90)

        #interp.plot_top_losses(2, figsize=(10,11))
        
        print("\n")
'''

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from sklearn.metrics import confusion_matrix
import seaborn as sns
# Out:
# 2023-05-30 12:32:22.142819: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pathlib
data_dir = pathlib.Path('./DATASET').with_suffix('')

# %%
data_dir
# Out:
# Path('DATASET')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1440

# %%
anger = list(data_dir.glob('angry/*'))
PIL.Image.open(str(anger[0]))
PIL.Image.open(str(anger[1]))

calm = list(data_dir.glob('calm/*'))
PIL.Image.open(str(calm[0]))
PIL.Image.open(str(calm[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
batch_size = 32
img_height = 240
img_width = 320

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1440 files belonging to 8 classes.
# Using 1152 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1440 files belonging to 8 classes.
# Using 288 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'calm', 'disgust', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 240, 320, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 240, 320, 3)       0
#
#  conv2d (Conv2D)             (None, 240, 320, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 120, 160, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 120, 160, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 60, 80, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 80, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 40, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 76800)             0
#
#  dense (Dense)               (None, 128)               9830528
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 9,855,144
# Trainable params: 9,855,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 36/36 [==============================] - 39s 1s/step - loss: 2.9010 - accuracy: 0.1484 - val_loss: 1.9151 - val_accuracy: 0.2188
# Epoch 2/10
# 36/36 [==============================] - 38s 1s/step - loss: 1.8161 - accuracy: 0.2604 - val_loss: 1.8199 - val_accuracy: 0.2188
# Epoch 3/10
# 36/36 [==============================] - 33s 923ms/step - loss: 1.6836 - accuracy: 0.3247 - val_loss: 1.7262 - val_accuracy: 0.3507
# Epoch 4/10
# 36/36 [==============================] - 33s 930ms/step - loss: 1.5959 - accuracy: 0.4045 - val_loss: 1.6765 - val_accuracy: 0.3090
# Epoch 5/10
# 36/36 [==============================] - 33s 922ms/step - loss: 1.4236 - accuracy: 0.4878 - val_loss: 1.6383 - val_accuracy: 0.3819
# Epoch 6/10
# 36/36 [==============================] - 33s 922ms/step - loss: 1.2863 - accuracy: 0.5451 - val_loss: 1.5524 - val_accuracy: 0.4271
# Epoch 7/10
# 36/36 [==============================] - 32s 885ms/step - loss: 1.1416 - accuracy: 0.5807 - val_loss: 1.6183 - val_accuracy: 0.4167
# Epoch 8/10
# 36/36 [==============================] - 34s 952ms/step - loss: 1.0818 - accuracy: 0.6163 - val_loss: 1.5070 - val_accuracy: 0.4583
# Epoch 9/10
# 36/36 [==============================] - 31s 870ms/step - loss: 0.8717 - accuracy: 0.6927 - val_loss: 1.3457 - val_accuracy: 0.4861
# Epoch 10/10
# 36/36 [==============================] - 33s 910ms/step - loss: 0.7025 - accuracy: 0.7569 - val_loss: 1.5840 - val_accuracy: 0.4792

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Get the predictions from the model
predictions = model.predict(val_ds)
predicted_classes = np.argmax(predictions, axis=1)

# Get the true labels
true_labels = []
for images, labels in val_ds:
    true_labels.extend(labels.numpy())

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_classes)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 9/9 [==============================] - 3s 272ms/step

# %%
# Fight overfitting by using data augmentation
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
# Utilizing Dropout
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tf/31f0rc1x5k50qxxnbl8gjc1c0000gn/T/ipykernel_81255/216251474.py in <module>
#       1 # Utilizing Dropout
# ----> 2 model = Sequential([
#       3   data_augmentation,
#       4   layers.Rescaling(1./255),
#       5   layers.Conv2D(16, 3, padding='same', activation='relu'),
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_7 (Sequential)   (None, 480, 640, 3)       0
#
#  rescaling_9 (Rescaling)     (None, 480, 640, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 480, 640, 16)      448
#
#  max_pooling2d_15 (MaxPoolin  (None, 240, 320, 16)     0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 240, 320, 32)      4640
#
#  max_pooling2d_16 (MaxPoolin  (None, 120, 160, 32)     0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 120, 160, 64)      18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 60, 80, 64)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 60, 80, 64)        0
#
#  flatten_5 (Flatten)         (None, 307200)            0
#
#  dense_9 (Dense)             (None, 128)               39321728
#
#  outputs (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 39,346,344
# Trainable params: 39,346,344
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 36/36 [==============================] - 208s 6s/step - loss: 3.7824 - accuracy: 0.1667 - val_loss: 2.0148 - val_accuracy: 0.1632
# Epoch 2/15
# 36/36 [==============================] - 163s 5s/step - loss: 1.9218 - accuracy: 0.2274 - val_loss: 1.9252 - val_accuracy: 0.2292
# Epoch 3/15
# 36/36 [==============================] - 154s 4s/step - loss: 1.8348 - accuracy: 0.2700 - val_loss: 1.8931 - val_accuracy: 0.2569
# Epoch 4/15
# 36/36 [==============================] - 156s 4s/step - loss: 1.7951 - accuracy: 0.2812 - val_loss: 1.9003 - val_accuracy: 0.2639
# Epoch 5/15
# 36/36 [==============================] - 156s 4s/step - loss: 1.7645 - accuracy: 0.2873 - val_loss: 1.9284 - val_accuracy: 0.2361
# Epoch 6/15
# 36/36 [==============================] - 157s 4s/step - loss: 1.7268 - accuracy: 0.3082 - val_loss: 1.9100 - val_accuracy: 0.2535
# Epoch 7/15
# 36/36 [==============================] - 155s 4s/step - loss: 1.6767 - accuracy: 0.3559 - val_loss: 1.8403 - val_accuracy: 0.2569
# Epoch 8/15
# 36/36 [==============================] - 155s 4s/step - loss: 1.6389 - accuracy: 0.3663 - val_loss: 1.8933 - val_accuracy: 0.2465
# Epoch 9/15
# 36/36 [==============================] - 169s 5s/step - loss: 1.5991 - accuracy: 0.3976 - val_loss: 1.9062 - val_accuracy: 0.2882
# Epoch 10/15
# 36/36 [==============================] - 206s 6s/step - loss: 1.5541 - accuracy: 0.4167 - val_loss: 1.8532 - val_accuracy: 0.2951
# Epoch 11/15
# 36/36 [==============================] - 216s 6s/step - loss: 1.5566 - accuracy: 0.4054 - val_loss: 1.8588 - val_accuracy: 0.2743
# Epoch 12/15
# 36/36 [==============================] - 155s 4s/step - loss: 1.4892 - accuracy: 0.4340 - val_loss: 1.8368 - val_accuracy: 0.2812
# Epoch 13/15
# 36/36 [==============================] - 155s 4s/step - loss: 1.4723 - accuracy: 0.4549 - val_loss: 1.9145 - val_accuracy: 0.2708
# Epoch 14/15
# 36/36 [==============================] - 153s 4s/step - loss: 1.4410 - accuracy: 0.4601 - val_loss: 1.9278 - val_accuracy: 0.2708
# Epoch 15/15
# 36/36 [==============================] - 152s 4s/step - loss: 1.4568 - accuracy: 0.4479 - val_loss: 1.8989 - val_accuracy: 0.2674

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tf/31f0rc1x5k50qxxnbl8gjc1c0000gn/T/ipykernel_81255/3592933492.py in <module>
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3
#       4 loss = history.history['loss']
#       5 val_loss = history.history['val_loss']
#
# NameError: name 'history' is not defined

# %%
# Get the predictions from the model
predictions = model.predict(val_ds)
predicted_classes = np.argmax(predictions, axis=1)

# Get the true labels
true_labels = []
for images, labels in val_ds:
    true_labels.extend(labels.numpy())

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_classes)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Confusion Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tf/31f0rc1x5k50qxxnbl8gjc1c0000gn/T/ipykernel_81255/1207246228.py in <module>
#       1 # Get the predictions from the model
# ----> 2 predictions = model.predict(val_ds)
#       3 predicted_classes = np.argmax(predictions, axis=1)
#       4
#       5 # Get the true labels
#
# NameError: name 'model' is not defined

# %%
location = './DATASET/angry/angry000001.jpg'
#file_path = tf.keras.utils.get_file('thingo', origin=location)

#img = pathlib.Path('./DATASET/angry/angry000001.jpg')

img = tf.keras.utils.load_img(
   location, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])



sorted_predictions = np.argsort(score)[::-1]

# Take the top five predictions.
top_predictions = sorted_predictions[:5]

# Print the top five predictions.
for i in range(len(top_predictions)):
    print(
        "The image most likely belongs to {} with a {:.4f} percent confidence."
        .format(class_names[top_predictions[i]], 100 * score[top_predictions[i]])
    )
# Out:
# 1/1 [==============================] - 0s 79ms/step
# The image most likely belongs to fearful with a 25.3286 percent confidence.
# The image most likely belongs to angry with a 22.0573 percent confidence.
# The image most likely belongs to surprised with a 20.7071 percent confidence.
# The image most likely belongs to happy with a 14.3433 percent confidence.
# The image most likely belongs to disgust with a 11.8499 percent confidence.
